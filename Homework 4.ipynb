# %% [markdown]
# <span style="font-size:large;">
# <div style="text-align: right">CSTS-UH 1078 <b>Networks</b><br/>
# Student name: <span style="color:blue"><b>Sashank Silwal</b></span><br/>
# Grade: <span style="color:red"><b></b></span><br/><br/></div>

# %% [markdown]
# ## <span style="color:red">HOMEWORK 4</span>
# # <span style="color:green">Basic Types of Networks

# %% [markdown]
# <span style="font-size:large;">
#
# * Undirected and Directed Networks
#
# * Simple, Multi-Linked Networks (or Multigraphs) and Weighted Networks
#
# * Complete Networks, Regular Graphs and Trees
#
# * Two-Mode Networks (or Bipartite Graphs)
#
# * Types of Connectedness
#
# * Network Density, Transitivity and Reciprocity

# %%
import pickle
import networkx as nx
from networkx.algorithms import bipartite
import matplotlib.pyplot as plt
from collections import Counter
import random
import math
import numpy as np
import pickle
import pygraphviz
from networkx.drawing.nx_agraph import graphviz_layout
from networkx.drawing.nx_agraph import to_agraph

# %% [markdown]
# ### 1. Undirected Simple Graphs

# %% [markdown]
# #### 1.0 Erdos-Renyi Random Undirected Graph

# %%
nodes=random.randint(47,52)
p=random.uniform(0.05,0.08)
name="Erdos-Renyi random graph"
G=nx.erdos_renyi_graph(nodes,p)
print "Graph G is a %s with %i nodes, p=%.3f and %i edges\n" %(name,len(G.nodes()),p,len(G.edges()))
# Out:
# Graph G is a Erdos-Renyi random graph with 52 nodes, p=0.079 and 116 edges

# %%
if G.is_multigraph()==True:
    print "G is a multigraph"
else:
    print "G is a simple graph"
if nx.is_weighted(G)==True:
    print "G is a weighted graph"
else:
    print "G is an unweighted graph"
if G.is_directed()==True:
    print "G is a directed graph"
else:
    print "G is an undirected graph"    
if nx.is_bipartite(G)==True:
    print "G is a bipartite graph"
else:
    print "G is not a bipartite graph"    
if nx.is_tree(G)==True:
    print "G is a tree"
else:
    print "G is not a tree"    
if G.is_directed()==False:
    if nx.is_connected(G)==True:
        print "G is a connected graph"
    else:
        print "G is a disconnected graph and it has",nx.number_connected_components(G),"connected components"    
else:
    if nx.is_strongly_connected(G)==True:
        print "G is a strongly connected graph"
    else:
        print "G is not strongly connected and it has",nx.number_strongly_connected_components(G),"strongly connected components"
    if nx.is_weakly_connected(G)==True:
        print "G is a weakly connected graph"
    else:
        print "G is not weakly connected and it has",nx.number_weakly_connected_components(G),"weakly connected components"    
if len(list(nx.isolates(G)))>0:
    print "G has",len(list(nx.isolates(G))),"isolates"
else:
    print "G has no isolates"
print "G has density equal to %.4f" %nx.density(G)
if nx.is_weighted(G)==False:
    if G.is_multigraph()==False:
        print "G has transitivity equal to %.4f" %nx.transitivity(G)
    else:
        G1=nx.Graph(G)
        print "G has transitivity equal to %.4f" %nx.transitivity(G1)
else:
    G1=nx.Graph(G)
    print "G has transitivity equal to %.4f" %nx.transitivity(G1)
if G.is_multigraph()==False:
    print "G has reciprocity equal to %.4f" %nx.reciprocity(G)
else:
    G1=nx.Graph(G)
    print "G has reciprocity equal to %.4f" %nx.reciprocity(G1)
# Out:
# G is a simple graph
# G is an unweighted graph
# G is an undirected graph
# G is not a bipartite graph
# G is not a tree
# G is a disconnected graph and it has 2 connected components
# G has 1 isolates
# G has density equal to 0.0875
# G has transitivity equal to 0.0606
# G has reciprocity equal to 0.0000

# %%
pos=graphviz_layout(G)
plt.figure(figsize=(8,8));
nodes = nx.draw_networkx_nodes(G, pos, node_color="g", alpha=0.4)
nx.draw_networkx_edges(G, pos,arrowsize=20, edge_color="b", alpha=0.7)
nx.draw_networkx_labels(G, pos)
plt.axis('off');
plt.title(name,fontsize=15);

# %% [markdown]
# #### 1.1 My Hashtags Graph

# %% [markdown]
# UNCOMMENT THE NEXT CELL BEFORE RUNNING IT!!!!!!!

# %%
G=nx.read_gpickle("graph2.gpickle")

name="My Hashtags graph"
print "Graph G is %s with %i nodes and %i edges\n" %(name,len(G.nodes()),len(G.edges()))
# Out:
# Graph G is My Hashtags graph with 247 nodes and 1187 edges

# %%
# Copy, paste and run cell 3 here:
if G.is_multigraph()==True:
    print "G is a multigraph"
else:
    print "G is a simple graph"
if nx.is_weighted(G)==True:
    print "G is a weighted graph"
else:
    print "G is an unweighted graph"
if G.is_directed()==True:
    print "G is a directed graph"
else:
    print "G is an undirected graph"    
if nx.is_bipartite(G)==True:
    print "G is a bipartite graph"
else:
    print "G is not a bipartite graph"    
if nx.is_tree(G)==True:
    print "G is a tree"
else:
    print "G is not a tree"    
if G.is_directed()==False:
    if nx.is_connected(G)==True:
        print "G is a connected graph"
    else:
        print "G is a disconnected graph and it has",nx.number_connected_components(G),"connected components"    
else:
    if nx.is_strongly_connected(G)==True:
        print "G is a strongly connected graph"
    else:
        print "G is not strongly connected and it has",nx.number_strongly_connected_components(G),"strongly connected components"
    if nx.is_weakly_connected(G)==True:
        print "G is a weakly connected graph"
    else:
        print "G is not weakly connected and it has",nx.number_weakly_connected_components(G),"weakly connected components"    
if len(list(nx.isolates(G)))>0:
    print "G has",len(list(nx.isolates(G))),"isolates"
else:
    print "G has no isolates"
print "G has density equal to %.4f" %nx.density(G)
if nx.is_weighted(G)==False:
    if G.is_multigraph()==False:
        print "G has transitivity equal to %.4f" %nx.transitivity(G)
    else:
        G1=nx.Graph(G)
        print "G has transitivity equal to %.4f" %nx.transitivity(G1)
else:
    G1=nx.Graph(G)
    print "G has transitivity equal to %.4f" %nx.transitivity(G1)
if G.is_multigraph()==False:
    print "G has reciprocity equal to %.4f" %nx.reciprocity(G)
else:
    G1=nx.Graph(G)
    print "G has reciprocity equal to %.4f" %nx.reciprocity(G1)
# Out:
# G is a multigraph
# G is an unweighted graph
# G is an undirected graph
# G is not a bipartite graph
# G is not a tree
# G is a disconnected graph and it has 46 connected components
# G has 8 isolates
# G has density equal to 0.0391
# G has transitivity equal to 0.2704
# G has reciprocity equal to 0.0000

# %% [markdown]
# #### 1.2 Gnm Random Undirected Graph

# %%
nodes=random.randint(47,52)
edges=random.randint(70,80)
name="Gnm random graph"
G=nx.gnm_random_graph(nodes,edges)
print "Graph G is a %s with %i nodes and %i edges\n" %(name,len(G.nodes()),len(G.edges()))
# Out:
# Graph G is a Gnm random graph with 48 nodes and 74 edges

# %%
# Copy, paste and run cell 3 here:
if G.is_multigraph()==True:
    print "G is a multigraph"
else:
    print "G is a simple graph"
if nx.is_weighted(G)==True:
    print "G is a weighted graph"
else:
    print "G is an unweighted graph"
if G.is_directed()==True:
    print "G is a directed graph"
else:
    print "G is an undirected graph"    
if nx.is_bipartite(G)==True:
    print "G is a bipartite graph"
else:
    print "G is not a bipartite graph"    
if nx.is_tree(G)==True:
    print "G is a tree"
else:
    print "G is not a tree"    
if G.is_directed()==False:
    if nx.is_connected(G)==True:
        print "G is a connected graph"
    else:
        print "G is a disconnected graph and it has",nx.number_connected_components(G),"connected components"    
else:
    if nx.is_strongly_connected(G)==True:
        print "G is a strongly connected graph"
    else:
        print "G is not strongly connected and it has",nx.number_strongly_connected_components(G),"strongly connected components"
    if nx.is_weakly_connected(G)==True:
        print "G is a weakly connected graph"
    else:
        print "G is not weakly connected and it has",nx.number_weakly_connected_components(G),"weakly connected components"    
if len(list(nx.isolates(G)))>0:
    print "G has",len(list(nx.isolates(G))),"isolates"
else:
    print "G has no isolates"
print "G has density equal to %.4f" %nx.density(G)
if nx.is_weighted(G)==False:
    if G.is_multigraph()==False:
        print "G has transitivity equal to %.4f" %nx.transitivity(G)
    else:
        G1=nx.Graph(G)
        print "G has transitivity equal to %.4f" %nx.transitivity(G1)
else:
    G1=nx.Graph(G)
    print "G has transitivity equal to %.4f" %nx.transitivity(G1)
if G.is_multigraph()==False:
    print "G has reciprocity equal to %.4f" %nx.reciprocity(G)
else:
    G1=nx.Graph(G)
    print "G has reciprocity equal to %.4f" %nx.reciprocity(G1)
# Out:
# G is a simple graph
# G is an unweighted graph
# G is an undirected graph
# G is not a bipartite graph
# G is not a tree
# G is a disconnected graph and it has 4 connected components
# G has 3 isolates
# G has density equal to 0.0656
# G has transitivity equal to 0.0417
# G has reciprocity equal to 0.0000

# %%
# Copy, paste and run cell 4 here:
pos=graphviz_layout(G)
plt.figure(figsize=(8,8));
nodes = nx.draw_networkx_nodes(G, pos, node_color="g", alpha=0.4)
nx.draw_networkx_edges(G, pos,arrowsize=20, edge_color="b", alpha=0.7)
nx.draw_networkx_labels(G, pos)
plt.axis('off');
plt.title(name,fontsize=15);

# %% [markdown]
# #### 1.3 Strogatz-Watts Small-World Graph

# %%
nodes=random.randint(47,52)
k=random.randint(5,8) #Each node is joined with its k nearest neighbors in a ring topology
p=random.uniform(0.7,0.8) #rewiring probability
name="Strogatz-Watts graph"
G=nx.watts_strogatz_graph(nodes, k, p)
print "Graph G is a %s with %i nodes, k=%i, p=%.2f and %i edges\n" %(name,len(G.nodes()),k,p,len(G.edges()))
# Out:
# Graph G is a Strogatz-Watts graph with 47 nodes, k=6, p=0.74 and 141 edges

# %%
# Copy, paste and run cell 3 here:
if G.is_multigraph()==True:
    print "G is a multigraph"
else:
    print "G is a simple graph"
if nx.is_weighted(G)==True:
    print "G is a weighted graph"
else:
    print "G is an unweighted graph"
if G.is_directed()==True:
    print "G is a directed graph"
else:
    print "G is an undirected graph"    
if nx.is_bipartite(G)==True:
    print "G is a bipartite graph"
else:
    print "G is not a bipartite graph"    
if nx.is_tree(G)==True:
    print "G is a tree"
else:
    print "G is not a tree"    
if G.is_directed()==False:
    if nx.is_connected(G)==True:
        print "G is a connected graph"
    else:
        print "G is a disconnected graph and it has",nx.number_connected_components(G),"connected components"    
else:
    if nx.is_strongly_connected(G)==True:
        print "G is a strongly connected graph"
    else:
        print "G is not strongly connected and it has",nx.number_strongly_connected_components(G),"strongly connected components"
    if nx.is_weakly_connected(G)==True:
        print "G is a weakly connected graph"
    else:
        print "G is not weakly connected and it has",nx.number_weakly_connected_components(G),"weakly connected components"    
if len(list(nx.isolates(G)))>0:
    print "G has",len(list(nx.isolates(G))),"isolates"
else:
    print "G has no isolates"
print "G has density equal to %.4f" %nx.density(G)
if nx.is_weighted(G)==False:
    if G.is_multigraph()==False:
        print "G has transitivity equal to %.4f" %nx.transitivity(G)
    else:
        G1=nx.Graph(G)
        print "G has transitivity equal to %.4f" %nx.transitivity(G1)
else:
    G1=nx.Graph(G)
    print "G has transitivity equal to %.4f" %nx.transitivity(G1)
if G.is_multigraph()==False:
    print "G has reciprocity equal to %.4f" %nx.reciprocity(G)
else:
    G1=nx.Graph(G)
    print "G has reciprocity equal to %.4f" %nx.reciprocity(G1)
# Out:
# G is a simple graph
# G is an unweighted graph
# G is an undirected graph
# G is not a bipartite graph
# G is not a tree
# G is a connected graph
# G has no isolates
# G has density equal to 0.1304
# G has transitivity equal to 0.0924
# G has reciprocity equal to 0.0000

# %%
# Copy, paste and run cell 4 here:
pos=graphviz_layout(G)
plt.figure(figsize=(8,8));
nodes = nx.draw_networkx_nodes(G, pos, node_color="g", alpha=0.4)
nx.draw_networkx_edges(G, pos,arrowsize=20, edge_color="b", alpha=0.7)
nx.draw_networkx_labels(G, pos)
plt.axis('off');
plt.title(name,fontsize=15);

# %% [markdown]
# #### 1.4 Barabasi-Albert Preferential Attachment Graph

# %%
n=random.randint(47,52) #no of nodes
m=random.randint(3,6) #Number of edges to attach from a new node to existing nodes
name="Barabasi-Albert graph"
G=nx.barabasi_albert_graph(n, m)
print "Graph G is a %s with %i nodes, m=%i and %i edges\n" %(name,len(G.nodes()),m,len(G.edges()))
# Out:
# Graph G is a Barabasi-Albert graph with 50 nodes, m=3 and 141 edges

# %%
# Copy, paste and run cell 3 here:
if G.is_multigraph()==True:
    print "G is a multigraph"
else:
    print "G is a simple graph"
if nx.is_weighted(G)==True:
    print "G is a weighted graph"
else:
    print "G is an unweighted graph"
if G.is_directed()==True:
    print "G is a directed graph"
else:
    print "G is an undirected graph"    
if nx.is_bipartite(G)==True:
    print "G is a bipartite graph"
else:
    print "G is not a bipartite graph"    
if nx.is_tree(G)==True:
    print "G is a tree"
else:
    print "G is not a tree"    
if G.is_directed()==False:
    if nx.is_connected(G)==True:
        print "G is a connected graph"
    else:
        print "G is a disconnected graph and it has",nx.number_connected_components(G),"connected components"    
else:
    if nx.is_strongly_connected(G)==True:
        print "G is a strongly connected graph"
    else:
        print "G is not strongly connected and it has",nx.number_strongly_connected_components(G),"strongly connected components"
    if nx.is_weakly_connected(G)==True:
        print "G is a weakly connected graph"
    else:
        print "G is not weakly connected and it has",nx.number_weakly_connected_components(G),"weakly connected components"    
if len(list(nx.isolates(G)))>0:
    print "G has",len(list(nx.isolates(G))),"isolates"
else:
    print "G has no isolates"
print "G has density equal to %.4f" %nx.density(G)
if nx.is_weighted(G)==False:
    if G.is_multigraph()==False:
        print "G has transitivity equal to %.4f" %nx.transitivity(G)
    else:
        G1=nx.Graph(G)
        print "G has transitivity equal to %.4f" %nx.transitivity(G1)
else:
    G1=nx.Graph(G)
    print "G has transitivity equal to %.4f" %nx.transitivity(G1)
if G.is_multigraph()==False:
    print "G has reciprocity equal to %.4f" %nx.reciprocity(G)
else:
    G1=nx.Graph(G)
    print "G has reciprocity equal to %.4f" %nx.reciprocity(G1)
# Out:
# G is a simple graph
# G is an unweighted graph
# G is an undirected graph
# G is not a bipartite graph
# G is not a tree
# G is a connected graph
# G has no isolates
# G has density equal to 0.1151
# G has transitivity equal to 0.1538
# G has reciprocity equal to 0.0000

# %%
# Copy, paste and run cell 4 here:
pos=graphviz_layout(G)
plt.figure(figsize=(8,8));
nodes = nx.draw_networkx_nodes(G, pos, node_color="g", alpha=0.4)
nx.draw_networkx_edges(G, pos,arrowsize=20, edge_color="b", alpha=0.7)
nx.draw_networkx_labels(G, pos)
plt.axis('off');
plt.title(name,fontsize=15);

# %% [markdown]
# #### 1.5 Random Regular Graph

# %%
while True:
    n=random.randint(47,52) #no of nodes
    d=random.randint(5,8) #the common degree of nodes
    if n*d%2==0:
        break
name="Random regular graph"
G=nx.random_regular_graph(d, n)
print "Graph G is a %s with %i nodes, d=%i and %i edges\n" %(name,len(G.nodes()),d,len(G.edges()))
# Out:
# Graph G is a Random regular graph with 48 nodes, d=8 and 192 edges

# %%
# Copy, paste and run cell 3 here:

if G.is_multigraph()==True:
    print "G is a multigraph"
else:
    print "G is a simple graph"
if nx.is_weighted(G)==True:
    print "G is a weighted graph"
else:
    print "G is an unweighted graph"
if G.is_directed()==True:
    print "G is a directed graph"
else:
    print "G is an undirected graph"    
if nx.is_bipartite(G)==True:
    print "G is a bipartite graph"
else:
    print "G is not a bipartite graph"    
if nx.is_tree(G)==True:
    print "G is a tree"
else:
    print "G is not a tree"    
if G.is_directed()==False:
    if nx.is_connected(G)==True:
        print "G is a connected graph"
    else:
        print "G is a disconnected graph and it has",nx.number_connected_components(G),"connected components"    
else:
    if nx.is_strongly_connected(G)==True:
        print "G is a strongly connected graph"
    else:
        print "G is not strongly connected and it has",nx.number_strongly_connected_components(G),"strongly connected components"
    if nx.is_weakly_connected(G)==True:
        print "G is a weakly connected graph"
    else:
        print "G is not weakly connected and it has",nx.number_weakly_connected_components(G),"weakly connected components"    
if len(list(nx.isolates(G)))>0:
    print "G has",len(list(nx.isolates(G))),"isolates"
else:
    print "G has no isolates"
print "G has density equal to %.4f" %nx.density(G)
if nx.is_weighted(G)==False:
    if G.is_multigraph()==False:
        print "G has transitivity equal to %.4f" %nx.transitivity(G)
    else:
        G1=nx.Graph(G)
        print "G has transitivity equal to %.4f" %nx.transitivity(G1)
else:
    G1=nx.Graph(G)
    print "G has transitivity equal to %.4f" %nx.transitivity(G1)
if G.is_multigraph()==False:
    print "G has reciprocity equal to %.4f" %nx.reciprocity(G)
else:
    G1=nx.Graph(G)
    print "G has reciprocity equal to %.4f" %nx.reciprocity(G1)
# Out:
# G is a simple graph
# G is an unweighted graph
# G is an undirected graph
# G is not a bipartite graph
# G is not a tree
# G is a connected graph
# G has no isolates
# G has density equal to 0.1702
# G has transitivity equal to 0.1250
# G has reciprocity equal to 0.0000

# %%
# Copy, paste and run cell 4 here:
pos=graphviz_layout(G)
plt.figure(figsize=(8,8));
nodes = nx.draw_networkx_nodes(G, pos, node_color="g", alpha=0.4)
nx.draw_networkx_edges(G, pos,arrowsize=20, edge_color="b", alpha=0.7)
nx.draw_networkx_labels(G, pos)
plt.axis('off');
plt.title(name,fontsize=15);

# %% [markdown]
# ### 2. Directed Simple Graphs

# %% [markdown]
# #### 2.0a My Wikipedia Graph

# %% [markdown]
# UNCOMMENT THE NEXT CELL BEFORE RUNNING IT!!!!!!!

# %%
G=nx.read_gpickle("graph1.gpickle")

name="My Wikipedia graph"
print "Graph G is %s with %i nodes and %i edges\n" %(name,len(G.nodes()),len(G.edges()))
# Out:
# Graph G is My Wikipedia graph with 14 nodes and 25 edges

# %%
# Copy, paste and run cell 3 here:
if G.is_multigraph()==True:
    print "G is a multigraph"
else:
    print "G is a simple graph"
if nx.is_weighted(G)==True:
    print "G is a weighted graph"
else:
    print "G is an unweighted graph"
if G.is_directed()==True:
    print "G is a directed graph"
else:
    print "G is an undirected graph"    
if nx.is_bipartite(G)==True:
    print "G is a bipartite graph"
else:
    print "G is not a bipartite graph"    
if nx.is_tree(G)==True:
    print "G is a tree"
else:
    print "G is not a tree"    
if G.is_directed()==False:
    if nx.is_connected(G)==True:
        print "G is a connected graph"
    else:
        print "G is a disconnected graph and it has",nx.number_connected_components(G),"connected components"    
else:
    if nx.is_strongly_connected(G)==True:
        print "G is a strongly connected graph"
    else:
        print "G is not strongly connected and it has",nx.number_strongly_connected_components(G),"strongly connected components"
    if nx.is_weakly_connected(G)==True:
        print "G is a weakly connected graph"
    else:
        print "G is not weakly connected and it has",nx.number_weakly_connected_components(G),"weakly connected components"    
if len(list(nx.isolates(G)))>0:
    print "G has",len(list(nx.isolates(G))),"isolates"
else:
    print "G has no isolates"
print "G has density equal to %.4f" %nx.density(G)
if nx.is_weighted(G)==False:
    if G.is_multigraph()==False:
        print "G has transitivity equal to %.4f" %nx.transitivity(G)
    else:
        G1=nx.Graph(G)
        print "G has transitivity equal to %.4f" %nx.transitivity(G1)
else:
    G1=nx.Graph(G)
    print "G has transitivity equal to %.4f" %nx.transitivity(G1)
if G.is_multigraph()==False:
    print "G has reciprocity equal to %.4f" %nx.reciprocity(G)
else:
    G1=nx.Graph(G)
    print "G has reciprocity equal to %.4f" %nx.reciprocity(G1)
# Out:
# G is a simple graph
# G is an unweighted graph
# G is a directed graph
# G is not a bipartite graph
# G is not a tree
# G is not strongly connected and it has 10 strongly connected components
# G is not weakly connected and it has 3 weakly connected components
# G has no isolates
# G has density equal to 0.1374
# G has transitivity equal to 0.6552
# G has reciprocity equal to 0.5600

# %% [markdown]
# #### 2.0b My Mentions Graph

# %% [markdown]
# UNCOMMENT THE NEXT CELL BEFORE RUNNING IT!!!!!!!

# %%
G=nx.read_gpickle("graph3.gpickle")

name="My Mentions graph"
print "Graph G is %s with %i nodes and %i edges\n" %(name,len(G.nodes()),len(G.edges()))
# Out:
# Graph G is My Mentions graph with 11215 nodes and 16817 edges

# %%
# Copy, paste and run cell 3 here:
if G.is_multigraph()==True:
    print "G is a multigraph"
else:
    print "G is a simple graph"
if nx.is_weighted(G)==True:
    print "G is a weighted graph"
else:
    print "G is an unweighted graph"
if G.is_directed()==True:
    print "G is a directed graph"
else:
    print "G is an undirected graph"    
if nx.is_bipartite(G)==True:
    print "G is a bipartite graph"
else:
    print "G is not a bipartite graph"    
if nx.is_tree(G)==True:
    print "G is a tree"
else:
    print "G is not a tree"    
if G.is_directed()==False:
    if nx.is_connected(G)==True:
        print "G is a connected graph"
    else:
        print "G is a disconnected graph and it has",nx.number_connected_components(G),"connected components"    
else:
    if nx.is_strongly_connected(G)==True:
        print "G is a strongly connected graph"
    else:
        print "G is not strongly connected and it has",nx.number_strongly_connected_components(G),"strongly connected components"
    if nx.is_weakly_connected(G)==True:
        print "G is a weakly connected graph"
    else:
        print "G is not weakly connected and it has",nx.number_weakly_connected_components(G),"weakly connected components"    
if len(list(nx.isolates(G)))>0:
    print "G has",len(list(nx.isolates(G))),"isolates"
else:
    print "G has no isolates"
print "G has density equal to %.4f" %nx.density(G)
if nx.is_weighted(G)==False:
    if G.is_multigraph()==False:
        print "G has transitivity equal to %.4f" %nx.transitivity(G)
    else:
        G1=nx.Graph(G)
        print "G has transitivity equal to %.4f" %nx.transitivity(G1)
else:
    G1=nx.Graph(G)
    print "G has transitivity equal to %.4f" %nx.transitivity(G1)
if G.is_multigraph()==False:
    print "G has reciprocity equal to %.4f" %nx.reciprocity(G)
else:
    G1=nx.Graph(G)
    print "G has reciprocity equal to %.4f" %nx.reciprocity(G1)
# Out:
# G is a multigraph
# G is an unweighted graph
# G is a directed graph
# G is not a bipartite graph
# G is not a tree
# G is not strongly connected and it has 11174 strongly connected components
# G is not weakly connected and it has 536 weakly connected components
# G has no isolates
# G has density equal to 0.0001
# G has transitivity equal to 0.0017
# G has reciprocity equal to 0.0000

# %% [markdown]
# #### 2.1 Erdos-Renyi Random Directed Graph

# %%
nodes=random.randint(37,42)
p=random.uniform(0.05,0.08)
name="Erdos-Renyi random graph"
G=nx.erdos_renyi_graph(nodes,p,directed=True)
print "Directed graph G is a %s with %i nodes, p=%.3f and %i edges\n" %(name,len(G.nodes()),p,len(G.edges()))
# Out:
# Directed graph G is a Erdos-Renyi random graph with 42 nodes, p=0.060 and 102 edges

# %%
# Copy, paste and run cell 3 here:
if G.is_multigraph()==True:
    print "G is a multigraph"
else:
    print "G is a simple graph"
if nx.is_weighted(G)==True:
    print "G is a weighted graph"
else:
    print "G is an unweighted graph"
if G.is_directed()==True:
    print "G is a directed graph"
else:
    print "G is an undirected graph"    
if nx.is_bipartite(G)==True:
    print "G is a bipartite graph"
else:
    print "G is not a bipartite graph"    
if nx.is_tree(G)==True:
    print "G is a tree"
else:
    print "G is not a tree"    
if G.is_directed()==False:
    if nx.is_connected(G)==True:
        print "G is a connected graph"
    else:
        print "G is a disconnected graph and it has",nx.number_connected_components(G),"connected components"    
else:
    if nx.is_strongly_connected(G)==True:
        print "G is a strongly connected graph"
    else:
        print "G is not strongly connected and it has",nx.number_strongly_connected_components(G),"strongly connected components"
    if nx.is_weakly_connected(G)==True:
        print "G is a weakly connected graph"
    else:
        print "G is not weakly connected and it has",nx.number_weakly_connected_components(G),"weakly connected components"    
if len(list(nx.isolates(G)))>0:
    print "G has",len(list(nx.isolates(G))),"isolates"
else:
    print "G has no isolates"
print "G has density equal to %.4f" %nx.density(G)
if nx.is_weighted(G)==False:
    if G.is_multigraph()==False:
        print "G has transitivity equal to %.4f" %nx.transitivity(G)
    else:
        G1=nx.Graph(G)
        print "G has transitivity equal to %.4f" %nx.transitivity(G1)
else:
    G1=nx.Graph(G)
    print "G has transitivity equal to %.4f" %nx.transitivity(G1)
if G.is_multigraph()==False:
    print "G has reciprocity equal to %.4f" %nx.reciprocity(G)
else:
    G1=nx.Graph(G)
    print "G has reciprocity equal to %.4f" %nx.reciprocity(G1)
# Out:
# G is a simple graph
# G is an unweighted graph
# G is a directed graph
# G is not a bipartite graph
# G is not a tree
# G is not strongly connected and it has 8 strongly connected components
# G is a weakly connected graph
# G has no isolates
# G has density equal to 0.0592
# G has transitivity equal to 0.0513
# G has reciprocity equal to 0.0196

# %%
# Copy, paste and run cell 4 here:
pos=graphviz_layout(G)
plt.figure(figsize=(8,8));
nodes = nx.draw_networkx_nodes(G, pos, node_color="g", alpha=0.4)
nx.draw_networkx_edges(G, pos,arrowsize=20, edge_color="b", alpha=0.7)
nx.draw_networkx_labels(G, pos)
plt.axis('off');
plt.title(name,fontsize=15);

# %% [markdown]
# #### 2.2 Gnm Random Directed Graph

# %%
nodes=random.randint(37,42)
edges=random.randint(70,80)
name="Gnm random graph"
G=nx.gnm_random_graph(nodes,edges)
print "Directed graph G is a %s with %i nodes and %i edges" %(name,len(G.nodes()),len(G.edges()))
# Out:
# Directed graph G is a Gnm random graph with 42 nodes and 74 edges

# %%
# Copy, paste and run cell 3 here:

if G.is_multigraph()==True:
    print "G is a multigraph"
else:
    print "G is a simple graph"
if nx.is_weighted(G)==True:
    print "G is a weighted graph"
else:
    print "G is an unweighted graph"
if G.is_directed()==True:
    print "G is a directed graph"
else:
    print "G is an undirected graph"    
if nx.is_bipartite(G)==True:
    print "G is a bipartite graph"
else:
    print "G is not a bipartite graph"    
if nx.is_tree(G)==True:
    print "G is a tree"
else:
    print "G is not a tree"    
if G.is_directed()==False:
    if nx.is_connected(G)==True:
        print "G is a connected graph"
    else:
        print "G is a disconnected graph and it has",nx.number_connected_components(G),"connected components"    
else:
    if nx.is_strongly_connected(G)==True:
        print "G is a strongly connected graph"
    else:
        print "G is not strongly connected and it has",nx.number_strongly_connected_components(G),"strongly connected components"
    if nx.is_weakly_connected(G)==True:
        print "G is a weakly connected graph"
    else:
        print "G is not weakly connected and it has",nx.number_weakly_connected_components(G),"weakly connected components"    
if len(list(nx.isolates(G)))>0:
    print "G has",len(list(nx.isolates(G))),"isolates"
else:
    print "G has no isolates"
print "G has density equal to %.4f" %nx.density(G)
if nx.is_weighted(G)==False:
    if G.is_multigraph()==False:
        print "G has transitivity equal to %.4f" %nx.transitivity(G)
    else:
        G1=nx.Graph(G)
        print "G has transitivity equal to %.4f" %nx.transitivity(G1)
else:
    G1=nx.Graph(G)
    print "G has transitivity equal to %.4f" %nx.transitivity(G1)
if G.is_multigraph()==False:
    print "G has reciprocity equal to %.4f" %nx.reciprocity(G)
else:
    G1=nx.Graph(G)
    print "G has reciprocity equal to %.4f" %nx.reciprocity(G1)
# Out:
# G is a simple graph
# G is an unweighted graph
# G is an undirected graph
# G is not a bipartite graph
# G is not a tree
# G is a disconnected graph and it has 4 connected components
# G has 2 isolates
# G has density equal to 0.0859
# G has transitivity equal to 0.1076
# G has reciprocity equal to 0.0000

# %%
# Copy, paste and run cell 4 here:
pos=graphviz_layout(G)
plt.figure(figsize=(8,8));
nodes = nx.draw_networkx_nodes(G, pos, node_color="g", alpha=0.4)
nx.draw_networkx_edges(G, pos,arrowsize=20, edge_color="b", alpha=0.7)
nx.draw_networkx_labels(G, pos)
plt.axis('off');
plt.title(name,fontsize=15);

# %% [markdown]
# ### 3. Bipartite Graphs

# %%
n = random.randint(10,15)   #nodes of the first partition
m = random.randint(10,15)   #nodes of the second partition
p=random.uniform(0.1,0.2)   #probability of edge existence
name="Bipartite random graph"
alls=[]
for y in range(n,n+m):
    for x in range(n):
        alls.append((x,y))
eds=random.sample(alls,int(p*len(alls)))
G=nx.Graph()
G.add_edges_from(eds)
X=[z for z in G.nodes() if z in range(n)]
Y=[z for z in G.nodes() if z in range(n,n+m)]
print "Graph G is a %s with %i nodes (%i nodes in the first partition, %i nodes in the second partition), p=%.2f and %i edges\n" %(name,len(G.nodes()),len(X),len(Y),p,len(G.edges()))
# Out:
# Graph G is a Bipartite random graph with 20 nodes (10 nodes in the first partition, 10 nodes in the second partition), p=0.11 and 18 edges

# %%
# Copy, paste and run cell 3 here:
if G.is_multigraph()==True:
    print "G is a multigraph"
else:
    print "G is a simple graph"
if nx.is_weighted(G)==True:
    print "G is a weighted graph"
else:
    print "G is an unweighted graph"
if G.is_directed()==True:
    print "G is a directed graph"
else:
    print "G is an undirected graph"    
if nx.is_bipartite(G)==True:
    print "G is a bipartite graph"
else:
    print "G is not a bipartite graph"    
if nx.is_tree(G)==True:
    print "G is a tree"
else:
    print "G is not a tree"    
if G.is_directed()==False:
    if nx.is_connected(G)==True:
        print "G is a connected graph"
    else:
        print "G is a disconnected graph and it has",nx.number_connected_components(G),"connected components"    
else:
    if nx.is_strongly_connected(G)==True:
        print "G is a strongly connected graph"
    else:
        print "G is not strongly connected and it has",nx.number_strongly_connected_components(G),"strongly connected components"
    if nx.is_weakly_connected(G)==True:
        print "G is a weakly connected graph"
    else:
        print "G is not weakly connected and it has",nx.number_weakly_connected_components(G),"weakly connected components"    
if len(list(nx.isolates(G)))>0:
    print "G has",len(list(nx.isolates(G))),"isolates"
else:
    print "G has no isolates"
print "G has density equal to %.4f" %nx.density(G)
if nx.is_weighted(G)==False:
    if G.is_multigraph()==False:
        print "G has transitivity equal to %.4f" %nx.transitivity(G)
    else:
        G1=nx.Graph(G)
        print "G has transitivity equal to %.4f" %nx.transitivity(G1)
else:
    G1=nx.Graph(G)
    print "G has transitivity equal to %.4f" %nx.transitivity(G1)
if G.is_multigraph()==False:
    print "G has reciprocity equal to %.4f" %nx.reciprocity(G)
else:
    G1=nx.Graph(G)
    print "G has reciprocity equal to %.4f" %nx.reciprocity(G1)
# Out:
# G is a simple graph
# G is an unweighted graph
# G is an undirected graph
# G is a bipartite graph
# G is not a tree
# G is a disconnected graph and it has 2 connected components
# G has no isolates
# G has density equal to 0.0947
# G has transitivity equal to 0.0000
# G has reciprocity equal to 0.0000

# %%
pos={}
for i,x in list(enumerate(X)):
    pos[x]=(0,i)
for j,y in list(enumerate(Y)):
    pos[y]=(1,j)
plt.figure(figsize=(8,8));
nodes1 = nx.draw_networkx_nodes(G, pos, nodelist=list(X), node_shape='o', node_color="g", alpha=0.4)
nodes2 = nx.draw_networkx_nodes(G, pos, nodelist=list(Y), node_shape='s', node_color="cyan", alpha=0.4)
nx.draw_networkx_edges(G, pos,arrowsize=20, edge_color="b", alpha=0.6)
nx.draw_networkx_labels(G, pos)
plt.axis('off');
plt.title(name,fontsize=15);

# %% [markdown]
# ### 4. Trees

# %% [markdown]
# #### 4.1 Balanced Tree

# %%
r=random.randint(2,3) #number of children of each node
h=random.randint(2,4) #number of generations (height)
name="Balanced tree"
G=nx.balanced_tree(r, h)
print "Tree G is a %s with %i nodes, r=%i, h=%i and %i edges" %(name,len(G.nodes()),r,h,len(G.edges()))
# Out:
# Tree G is a Balanced tree with 7 nodes, r=2, h=2 and 6 edges

# %%
# Copy, paste and run cell 3 here:
if G.is_multigraph()==True:
    print "G is a multigraph"
else:
    print "G is a simple graph"
if nx.is_weighted(G)==True:
    print "G is a weighted graph"
else:
    print "G is an unweighted graph"
if G.is_directed()==True:
    print "G is a directed graph"
else:
    print "G is an undirected graph"    
if nx.is_bipartite(G)==True:
    print "G is a bipartite graph"
else:
    print "G is not a bipartite graph"    
if nx.is_tree(G)==True:
    print "G is a tree"
else:
    print "G is not a tree"    
if G.is_directed()==False:
    if nx.is_connected(G)==True:
        print "G is a connected graph"
    else:
        print "G is a disconnected graph and it has",nx.number_connected_components(G),"connected components"    
else:
    if nx.is_strongly_connected(G)==True:
        print "G is a strongly connected graph"
    else:
        print "G is not strongly connected and it has",nx.number_strongly_connected_components(G),"strongly connected components"
    if nx.is_weakly_connected(G)==True:
        print "G is a weakly connected graph"
    else:
        print "G is not weakly connected and it has",nx.number_weakly_connected_components(G),"weakly connected components"    
if len(list(nx.isolates(G)))>0:
    print "G has",len(list(nx.isolates(G))),"isolates"
else:
    print "G has no isolates"
print "G has density equal to %.4f" %nx.density(G)
if nx.is_weighted(G)==False:
    if G.is_multigraph()==False:
        print "G has transitivity equal to %.4f" %nx.transitivity(G)
    else:
        G1=nx.Graph(G)
        print "G has transitivity equal to %.4f" %nx.transitivity(G1)
else:
    G1=nx.Graph(G)
    print "G has transitivity equal to %.4f" %nx.transitivity(G1)
if G.is_multigraph()==False:
    print "G has reciprocity equal to %.4f" %nx.reciprocity(G)
else:
    G1=nx.Graph(G)
    print "G has reciprocity equal to %.4f" %nx.reciprocity(G1)
# Out:
# G is a simple graph
# G is an unweighted graph
# G is an undirected graph
# G is a bipartite graph
# G is a tree
# G is a connected graph
# G has no isolates
# G has density equal to 0.2857
# G has transitivity equal to 0.0000
# G has reciprocity equal to 0.0000

# %%
plt.figure(figsize=(8,8));
pos=graphviz_layout(G, prog='dot') #, args="-Grankdir=LR")
nodes = nx.draw_networkx_nodes(G, pos, node_color="g", alpha=0.4)#,)
nx.draw_networkx_edges(G, pos, edge_color='b', alpha=0.7)
nx.draw_networkx_labels(G, pos,font_size=8)
plt.axis('off');
plt.title(name,fontsize=15);

# %% [markdown]
# #### 4.2 Random Power Law Tree

# %%
n=random.randint(25,35) #number of nodes
name="Random power law tree"
G=nx.random_powerlaw_tree(n,tries=1000)
print "Tree G is a %s with %i nodes and %i edges" %(name,len(G.nodes()),len(G.edges()))
# Out:
# Tree G is a Random power law tree with 33 nodes and 32 edges

# %%
# Copy, paste and run cell 3 here:
if G.is_multigraph()==True:
    print "G is a multigraph"
else:
    print "G is a simple graph"
if nx.is_weighted(G)==True:
    print "G is a weighted graph"
else:
    print "G is an unweighted graph"
if G.is_directed()==True:
    print "G is a directed graph"
else:
    print "G is an undirected graph"    
if nx.is_bipartite(G)==True:
    print "G is a bipartite graph"
else:
    print "G is not a bipartite graph"    
if nx.is_tree(G)==True:
    print "G is a tree"
else:
    print "G is not a tree"    
if G.is_directed()==False:
    if nx.is_connected(G)==True:
        print "G is a connected graph"
    else:
        print "G is a disconnected graph and it has",nx.number_connected_components(G),"connected components"    
else:
    if nx.is_strongly_connected(G)==True:
        print "G is a strongly connected graph"
    else:
        print "G is not strongly connected and it has",nx.number_strongly_connected_components(G),"strongly connected components"
    if nx.is_weakly_connected(G)==True:
        print "G is a weakly connected graph"
    else:
        print "G is not weakly connected and it has",nx.number_weakly_connected_components(G),"weakly connected components"    
if len(list(nx.isolates(G)))>0:
    print "G has",len(list(nx.isolates(G))),"isolates"
else:
    print "G has no isolates"
print "G has density equal to %.4f" %nx.density(G)
if nx.is_weighted(G)==False:
    if G.is_multigraph()==False:
        print "G has transitivity equal to %.4f" %nx.transitivity(G)
    else:
        G1=nx.Graph(G)
        print "G has transitivity equal to %.4f" %nx.transitivity(G1)
else:
    G1=nx.Graph(G)
    print "G has transitivity equal to %.4f" %nx.transitivity(G1)
if G.is_multigraph()==False:
    print "G has reciprocity equal to %.4f" %nx.reciprocity(G)
else:
    G1=nx.Graph(G)
    print "G has reciprocity equal to %.4f" %nx.reciprocity(G1)
# Out:
# G is a simple graph
# G is an unweighted graph
# G is an undirected graph
# G is a bipartite graph
# G is a tree
# G is a connected graph
# G has no isolates
# G has density equal to 0.0606
# G has transitivity equal to 0.0000
# G has reciprocity equal to 0.0000

# %%
# Copy, paste and run cell 28 here:
pos=graphviz_layout(G)
plt.figure(figsize=(8,8));
nodes = nx.draw_networkx_nodes(G, pos, node_color="g", alpha=0.4)
nx.draw_networkx_edges(G, pos,arrowsize=20, edge_color="b", alpha=0.7)
nx.draw_networkx_labels(G, pos)
plt.axis('off');
plt.title(name,fontsize=15);

# %% [markdown]
# ### 5. Weighted Graphs

# %% [markdown]
# #### Function alocating randomly integer weights on edges of a graph

# %%
def weight_attr(G,maxw):
    # G is a graph
    # maxw is a positive integer (maximum weight value)
    weight={}
    for edge in G.edges():
        ed=edge[0]
        de=edge[1]
        G[ed][de]['weight']=random.randrange(1,maxw)
        weight[(ed,de)]=G[ed][de]['weight']
    return weight

# %% [markdown]
# #### 5.1 Erdos-Renyi Random Weighted Graph

# %%
nodes=random.randint(47,52)
p=random.uniform(0.05,0.08)
name="Erdos-Renyi random weighted graph"
G=nx.erdos_renyi_graph(nodes,p)
maxw=random.randint(7,12)
weight=weight_attr(G,maxw)
w_edges=[(x,y,z) for (x,y),z in weight.items()]
G.add_weighted_edges_from(w_edges)
print "Graph G is a %s with %i nodes, p=%.3f and %i edges\n" %(name,len(G.nodes()),p,len(G.edges()))

res = list(sorted(Counter(G.edges()), key=Counter(G.edges()).__getitem__, reverse=True))
for i in res:
    print "Edge", i, "has weight", Counter(G.edges())[i]['weight']
# Out:
# Graph G is a Erdos-Renyi random weighted graph with 48 nodes, p=0.065 and 74 edges
#
# Edge (16, 35) has weight 11
# Edge (11, 23) has weight 11
# Edge (18, 19) has weight 11
# Edge (7, 15) has weight 11
# Edge (13, 36) has weight 11
# Edge (10, 38) has weight 11
# Edge (20, 39) has weight 11
# Edge (20, 40) has weight 11
# Edge (13, 19) has weight 11
# Edge (1, 27) has weight 11
# Edge (28, 44) has weight 11
# Edge (6, 16) has weight 11
# Edge (12, 44) has weight 10
# Edge (17, 29) has weight 10
# Edge (15, 20) has weight 10
# Edge (18, 25) has weight 10
# Edge (21, 24) has weight 10
# Edge (29, 31) has weight 9
# Edge (18, 41) has weight 9
# Edge (15, 19) has weight 9
# Edge (5, 14) has weight 9
# Edge (0, 29) has weight 9
# Edge (8, 18) has weight 9
# Edge (8, 26) has weight 9
# Edge (5, 27) has weight 9
# Edge (25, 40) has weight 9
# Edge (1, 46) has weight 8
# Edge (12, 24) has weight 8
# Edge (39, 44) has weight 8
# Edge (5, 17) has weight 8
# Edge (4, 43) has weight 8
# Edge (8, 28) has weight 7
# Edge (4, 33) has weight 7
# Edge (15, 30) has weight 7
# Edge (11, 36) has weight 7
# Edge (12, 27) has weight 6
# Edge (8, 10) has weight 6
# Edge (12, 36) has weight 6
# Edge (2, 12) has weight 6
# Edge (37, 46) has weight 6
# Edge (26, 43) has weight 6
# Edge (29, 41) has weight 6
# Edge (17, 21) has weight 6
# Edge (27, 30) has weight 6
# Edge (39, 41) has weight 5
# Edge (1, 2) has weight 5
# Edge (6, 32) has weight 5
# Edge (34, 47) has weight 5
# Edge (29, 38) has weight 5
# Edge (22, 29) has weight 5
# Edge (3, 8) has weight 5
# Edge (5, 6) has weight 4
# Edge (1, 36) has weight 4
# Edge (15, 34) has weight 4
# Edge (27, 44) has weight 4
# Edge (23, 34) has weight 4
# Edge (2, 32) has weight 4
# Edge (21, 22) has weight 4
# Edge (29, 44) has weight 3
# Edge (30, 36) has weight 3
# Edge (0, 36) has weight 2
# Edge (30, 33) has weight 2
# Edge (6, 37) has weight 2
# Edge (0, 22) has weight 2
# Edge (19, 28) has weight 2
# Edge (11, 37) has weight 2
# Edge (44, 46) has weight 2
# Edge (13, 27) has weight 2
# Edge (4, 44) has weight 2
# Edge (23, 32) has weight 2
# Edge (9, 44) has weight 1
# Edge (12, 14) has weight 1
# Edge (7, 40) has weight 1
# Edge (11, 20) has weight 1

# %%
# Copy, paste and run cell 3 here:
if G.is_multigraph()==True:
    print "G is a multigraph"
else:
    print "G is a simple graph"
if nx.is_weighted(G)==True:
    print "G is a weighted graph"
else:
    print "G is an unweighted graph"
if G.is_directed()==True:
    print "G is a directed graph"
else:
    print "G is an undirected graph"    
if nx.is_bipartite(G)==True:
    print "G is a bipartite graph"
else:
    print "G is not a bipartite graph"    
if nx.is_tree(G)==True:
    print "G is a tree"
else:
    print "G is not a tree"    
if G.is_directed()==False:
    if nx.is_connected(G)==True:
        print "G is a connected graph"
    else:
        print "G is a disconnected graph and it has",nx.number_connected_components(G),"connected components"    
else:
    if nx.is_strongly_connected(G)==True:
        print "G is a strongly connected graph"
    else:
        print "G is not strongly connected and it has",nx.number_strongly_connected_components(G),"strongly connected components"
    if nx.is_weakly_connected(G)==True:
        print "G is a weakly connected graph"
    else:
        print "G is not weakly connected and it has",nx.number_weakly_connected_components(G),"weakly connected components"    
if len(list(nx.isolates(G)))>0:
    print "G has",len(list(nx.isolates(G))),"isolates"
else:
    print "G has no isolates"
print "G has density equal to %.4f" %nx.density(G)
if nx.is_weighted(G)==False:
    if G.is_multigraph()==False:
        print "G has transitivity equal to %.4f" %nx.transitivity(G)
    else:
        G1=nx.Graph(G)
        print "G has transitivity equal to %.4f" %nx.transitivity(G1)
else:
    G1=nx.Graph(G)
    print "G has transitivity equal to %.4f" %nx.transitivity(G1)
if G.is_multigraph()==False:
    print "G has reciprocity equal to %.4f" %nx.reciprocity(G)
else:
    G1=nx.Graph(G)
    print "G has reciprocity equal to %.4f" %nx.reciprocity(G1)
# Out:
# G is a simple graph
# G is a weighted graph
# G is an undirected graph
# G is not a bipartite graph
# G is not a tree
# G is a disconnected graph and it has 3 connected components
# G has 2 isolates
# G has density equal to 0.0656
# G has transitivity equal to 0.0273
# G has reciprocity equal to 0.0000

# %%
edge_width=[G[u][v]['weight'] for u,v in G.edges()] 
edge_width=[w for w in edge_width]

pos=graphviz_layout(G)
plt.figure(figsize=(8,8));
nodes = nx.draw_networkx_nodes(G, pos, node_color="g", alpha=0.3)
nx.draw_networkx_edges(G, pos,arrowsize=20, width=edge_width, edge_color="b", alpha=0.5)
nx.draw_networkx_labels(G, pos)
plt.axis('off');
plt.title(name,fontsize=15);

# %% [markdown]
# #### 5.2 Gnm Random Weighted  Graph

# %%
nodes=random.randint(47,52)
edges=random.randint(70,80)
name="Gnm random weighted graph"
G=nx.gnm_random_graph(nodes,edges)
maxw=random.randint(7,12)
weight=weight_attr(G,maxw)
w_edges=[(x,y,z) for (x,y),z in weight.items()]
G.add_weighted_edges_from(w_edges)
print "Graph G is a %s with %i nodes and %i edges\n" %(name,len(G.nodes()),len(G.edges()))

res = list(sorted(Counter(G.edges()), key=Counter(G.edges()).__getitem__, reverse=True))
for i in res:
    print "Edge", i, "has weight", Counter(G.edges())[i]['weight']
# Out:
# Graph G is a Gnm random weighted graph with 49 nodes and 76 edges
#
# Edge (22, 37) has weight 11
# Edge (37, 43) has weight 11
# Edge (30, 48) has weight 11
# Edge (14, 34) has weight 11
# Edge (8, 11) has weight 11
# Edge (19, 40) has weight 11
# Edge (23, 48) has weight 11
# Edge (28, 30) has weight 11
# Edge (23, 28) has weight 11
# Edge (17, 36) has weight 10
# Edge (15, 38) has weight 10
# Edge (1, 21) has weight 9
# Edge (4, 23) has weight 9
# Edge (1, 10) has weight 9
# Edge (24, 39) has weight 9
# Edge (3, 19) has weight 9
# Edge (6, 12) has weight 9
# Edge (10, 13) has weight 9
# Edge (6, 38) has weight 9
# Edge (11, 41) has weight 9
# Edge (33, 45) has weight 8
# Edge (22, 26) has weight 8
# Edge (9, 41) has weight 8
# Edge (6, 14) has weight 8
# Edge (12, 17) has weight 8
# Edge (12, 34) has weight 8
# Edge (23, 29) has weight 8
# Edge (7, 22) has weight 8
# Edge (37, 44) has weight 8
# Edge (23, 37) has weight 7
# Edge (15, 32) has weight 7
# Edge (29, 43) has weight 7
# Edge (20, 41) has weight 7
# Edge (43, 48) has weight 6
# Edge (28, 29) has weight 6
# Edge (1, 11) has weight 6
# Edge (34, 43) has weight 6
# Edge (12, 43) has weight 6
# Edge (13, 15) has weight 6
# Edge (6, 31) has weight 6
# Edge (2, 18) has weight 5
# Edge (31, 32) has weight 5
# Edge (7, 23) has weight 5
# Edge (7, 14) has weight 5
# Edge (5, 45) has weight 5
# Edge (41, 48) has weight 5
# Edge (10, 21) has weight 4
# Edge (15, 42) has weight 4
# Edge (18, 23) has weight 4
# Edge (14, 21) has weight 4
# Edge (18, 26) has weight 3
# Edge (14, 47) has weight 3
# Edge (11, 13) has weight 3
# Edge (19, 46) has weight 3
# Edge (6, 13) has weight 3
# Edge (13, 32) has weight 2
# Edge (17, 33) has weight 2
# Edge (12, 48) has weight 2
# Edge (32, 33) has weight 2
# Edge (35, 43) has weight 2
# Edge (27, 40) has weight 2
# Edge (3, 4) has weight 2
# Edge (6, 9) has weight 1
# Edge (30, 41) has weight 1
# Edge (3, 28) has weight 1
# Edge (16, 47) has weight 1
# Edge (4, 33) has weight 1
# Edge (16, 36) has weight 1
# Edge (11, 22) has weight 1
# Edge (11, 35) has weight 1
# Edge (16, 33) has weight 1
# Edge (38, 41) has weight 1
# Edge (1, 47) has weight 1
# Edge (8, 18) has weight 1
# Edge (18, 42) has weight 1
# Edge (11, 39) has weight 1

# %%
# Copy, paste and run cell 3 here:

if G.is_multigraph()==True:
    print "G is a multigraph"
else:
    print "G is a simple graph"
if nx.is_weighted(G)==True:
    print "G is a weighted graph"
else:
    print "G is an unweighted graph"
if G.is_directed()==True:
    print "G is a directed graph"
else:
    print "G is an undirected graph"    
if nx.is_bipartite(G)==True:
    print "G is a bipartite graph"
else:
    print "G is not a bipartite graph"    
if nx.is_tree(G)==True:
    print "G is a tree"
else:
    print "G is not a tree"    
if G.is_directed()==False:
    if nx.is_connected(G)==True:
        print "G is a connected graph"
    else:
        print "G is a disconnected graph and it has",nx.number_connected_components(G),"connected components"    
else:
    if nx.is_strongly_connected(G)==True:
        print "G is a strongly connected graph"
    else:
        print "G is not strongly connected and it has",nx.number_strongly_connected_components(G),"strongly connected components"
    if nx.is_weakly_connected(G)==True:
        print "G is a weakly connected graph"
    else:
        print "G is not weakly connected and it has",nx.number_weakly_connected_components(G),"weakly connected components"    
if len(list(nx.isolates(G)))>0:
    print "G has",len(list(nx.isolates(G))),"isolates"
else:
    print "G has no isolates"
print "G has density equal to %.4f" %nx.density(G)
if nx.is_weighted(G)==False:
    if G.is_multigraph()==False:
        print "G has transitivity equal to %.4f" %nx.transitivity(G)
    else:
        G1=nx.Graph(G)
        print "G has transitivity equal to %.4f" %nx.transitivity(G1)
else:
    G1=nx.Graph(G)
    print "G has transitivity equal to %.4f" %nx.transitivity(G1)
if G.is_multigraph()==False:
    print "G has reciprocity equal to %.4f" %nx.reciprocity(G)
else:
    G1=nx.Graph(G)
    print "G has reciprocity equal to %.4f" %nx.reciprocity(G1)
# Out:
# G is a simple graph
# G is a weighted graph
# G is an undirected graph
# G is not a bipartite graph
# G is not a tree
# G is a disconnected graph and it has 3 connected components
# G has 2 isolates
# G has density equal to 0.0646
# G has transitivity equal to 0.0776
# G has reciprocity equal to 0.0000

# %%
# Copy, paste and run cell 35 here:

edge_width=[G[u][v]['weight'] for u,v in G.edges()] 
edge_width=[w for w in edge_width]

pos=graphviz_layout(G)
plt.figure(figsize=(8,8));
nodes = nx.draw_networkx_nodes(G, pos, node_color="g", alpha=0.3)
nx.draw_networkx_edges(G, pos,arrowsize=20, width=edge_width, edge_color="b", alpha=0.5)
nx.draw_networkx_labels(G, pos)
plt.axis('off');
plt.title(name,fontsize=15);

# %% [markdown]
# ### 6. Multigraphs

# %% [markdown]
# #### Function adding randomly multiple edges of a graph

# %%
def add_multiedges(G,k):
    # E is a list of edges
    # k is a positive integer for the edges to be added in parallen to existing ones 
    edges = list(G.edges())
    for _ in range(k):
        e=random.choice(list(E))
        edges.append(e)
    Gm = nx.MultiGraph()
    Gm.add_edges_from(edges)
    return Gm

# %% [markdown]
# #### 6.1 Gnm Random Multigraph

# %%
nodes=random.randint(17,22)
edges=random.randint(35,45)
name="Gnm random multigraph"
G=nx.gnm_random_graph(nodes,edges)
E=G.edges()
k=random.randint(50,60)
G=add_multiedges(G,k)
print "Graph G is a %s with %i nodes and %i edges\n" %(name,len(G.nodes()),len(G.edges()))

res = list(sorted(Counter(G.edges()), key=Counter(G.edges()).__getitem__, reverse=True))
for i in res:
    print "Edge", i, "appears", Counter(G.edges())[i], "times"
# Out:
# Graph G is a Gnm random multigraph with 20 nodes and 98 edges
#
# Edge (14, 16) appears 5 times
# Edge (3, 15) appears 4 times
# Edge (13, 17) appears 4 times
# Edge (8, 19) appears 4 times
# Edge (6, 7) appears 4 times
# Edge (5, 18) appears 4 times
# Edge (9, 17) appears 4 times
# Edge (14, 19) appears 4 times
# Edge (1, 8) appears 4 times
# Edge (5, 6) appears 3 times
# Edge (0, 14) appears 3 times
# Edge (0, 7) appears 3 times
# Edge (8, 10) appears 3 times
# Edge (10, 18) appears 3 times
# Edge (15, 19) appears 3 times
# Edge (9, 16) appears 3 times
# Edge (5, 19) appears 3 times
# Edge (13, 14) appears 3 times
# Edge (0, 2) appears 3 times
# Edge (14, 17) appears 2 times
# Edge (1, 15) appears 2 times
# Edge (7, 11) appears 2 times
# Edge (3, 7) appears 2 times
# Edge (16, 17) appears 2 times
# Edge (7, 14) appears 2 times
# Edge (3, 13) appears 2 times
# Edge (3, 9) appears 2 times
# Edge (1, 9) appears 2 times
# Edge (9, 13) appears 2 times
# Edge (4, 6) appears 2 times
# Edge (2, 18) appears 1 times
# Edge (12, 16) appears 1 times
# Edge (4, 12) appears 1 times
# Edge (7, 15) appears 1 times
# Edge (5, 12) appears 1 times
# Edge (3, 6) appears 1 times
# Edge (7, 10) appears 1 times
# Edge (3, 12) appears 1 times
# Edge (3, 4) appears 1 times

# %%
# Copy, paste and run cell 3 here:
if G.is_multigraph()==True:
    print "G is a multigraph"
else:
    print "G is a simple graph"
if nx.is_weighted(G)==True:
    print "G is a weighted graph"
else:
    print "G is an unweighted graph"
if G.is_directed()==True:
    print "G is a directed graph"
else:
    print "G is an undirected graph"    
if nx.is_bipartite(G)==True:
    print "G is a bipartite graph"
else:
    print "G is not a bipartite graph"    
if nx.is_tree(G)==True:
    print "G is a tree"
else:
    print "G is not a tree"    
if G.is_directed()==False:
    if nx.is_connected(G)==True:
        print "G is a connected graph"
    else:
        print "G is a disconnected graph and it has",nx.number_connected_components(G),"connected components"    
else:
    if nx.is_strongly_connected(G)==True:
        print "G is a strongly connected graph"
    else:
        print "G is not strongly connected and it has",nx.number_strongly_connected_components(G),"strongly connected components"
    if nx.is_weakly_connected(G)==True:
        print "G is a weakly connected graph"
    else:
        print "G is not weakly connected and it has",nx.number_weakly_connected_components(G),"weakly connected components"    
if len(list(nx.isolates(G)))>0:
    print "G has",len(list(nx.isolates(G))),"isolates"
else:
    print "G has no isolates"
print "G has density equal to %.4f" %nx.density(G)
if nx.is_weighted(G)==False:
    if G.is_multigraph()==False:
        print "G has transitivity equal to %.4f" %nx.transitivity(G)
    else:
        G1=nx.Graph(G)
        print "G has transitivity equal to %.4f" %nx.transitivity(G1)
else:
    G1=nx.Graph(G)
    print "G has transitivity equal to %.4f" %nx.transitivity(G1)
if G.is_multigraph()==False:
    print "G has reciprocity equal to %.4f" %nx.reciprocity(G)
else:
    G1=nx.Graph(G)
    print "G has reciprocity equal to %.4f" %nx.reciprocity(G1)
# Out:
# G is a multigraph
# G is an unweighted graph
# G is an undirected graph
# G is not a bipartite graph
# G is not a tree
# G is a connected graph
# G has no isolates
# G has density equal to 0.5158
# G has transitivity equal to 0.2239
# G has reciprocity equal to 0.0000

# %% [markdown]
# #### Plotting the multigraph as a weighted graph

# %%
weight=[(x, y, {'weight': v}) for (x, y), v in Counter(G.edges()).items()]
G = nx.Graph(weight)
edge_width=[G[u][v]['weight'] for u,v in G.edges()]

pos=graphviz_layout(G)
plt.figure(figsize=(8,8));
nodes = nx.draw_networkx_nodes(G, pos, node_color="g", alpha=0.3)
nx.draw_networkx_edges(G, pos,arrowsize=20, width=edge_width, edge_color="b", alpha=0.5)
nx.draw_networkx_labels(G, pos)
plt.axis('off');
plt.title(name,fontsize=15);

# %% [markdown]
# #### 6.2 Erdos-Renyi Random Multigraph

# %%
nodes=random.randint(27,32)
p=random.uniform(0.05,0.07)
name="Erdos-Renyi random multigraph"
G=nx.erdos_renyi_graph(nodes,p)
E=G.edges()
k=random.randint(50,60)
G=add_multiedges(G,k)
print "Graph G is a %s with %i nodes, p=%.3f and %i edges\n" %(name,len(G.nodes()),p,len(G.edges()))

res = list(sorted(Counter(G.edges()), key=Counter(G.edges()).__getitem__, reverse=True))
for i in res:
    print "Edge", i, "appears", Counter(G.edges())[i], "times"
# Out:
# Graph G is a Erdos-Renyi random multigraph with 29 nodes, p=0.066 and 84 edges
#
# Edge (0, 5) appears 6 times
# Edge (9, 17) appears 5 times
# Edge (14, 25) appears 5 times
# Edge (5, 7) appears 5 times
# Edge (19, 23) appears 5 times
# Edge (6, 9) appears 4 times
# Edge (13, 17) appears 4 times
# Edge (1, 28) appears 4 times
# Edge (14, 30) appears 3 times
# Edge (6, 28) appears 3 times
# Edge (13, 26) appears 3 times
# Edge (0, 15) appears 3 times
# Edge (14, 18) appears 3 times
# Edge (10, 18) appears 3 times
# Edge (12, 28) appears 3 times
# Edge (19, 24) appears 3 times
# Edge (26, 30) appears 3 times
# Edge (24, 29) appears 3 times
# Edge (0, 26) appears 3 times
# Edge (2, 23) appears 2 times
# Edge (24, 26) appears 2 times
# Edge (12, 22) appears 2 times
# Edge (7, 21) appears 1 times
# Edge (10, 11) appears 1 times
# Edge (3, 11) appears 1 times
# Edge (16, 19) appears 1 times
# Edge (13, 20) appears 1 times
# Edge (7, 22) appears 1 times
# Edge (8, 16) appears 1 times

# %%
# Copy, paste and run cell 3 here:
if G.is_multigraph()==True:
    print "G is a multigraph"
else:
    print "G is a simple graph"
if nx.is_weighted(G)==True:
    print "G is a weighted graph"
else:
    print "G is an unweighted graph"
if G.is_directed()==True:
    print "G is a directed graph"
else:
    print "G is an undirected graph"    
if nx.is_bipartite(G)==True:
    print "G is a bipartite graph"
else:
    print "G is not a bipartite graph"    
if nx.is_tree(G)==True:
    print "G is a tree"
else:
    print "G is not a tree"    
if G.is_directed()==False:
    if nx.is_connected(G)==True:
        print "G is a connected graph"
    else:
        print "G is a disconnected graph and it has",nx.number_connected_components(G),"connected components"    
else:
    if nx.is_strongly_connected(G)==True:
        print "G is a strongly connected graph"
    else:
        print "G is not strongly connected and it has",nx.number_strongly_connected_components(G),"strongly connected components"
    if nx.is_weakly_connected(G)==True:
        print "G is a weakly connected graph"
    else:
        print "G is not weakly connected and it has",nx.number_weakly_connected_components(G),"weakly connected components"    
if len(list(nx.isolates(G)))>0:
    print "G has",len(list(nx.isolates(G))),"isolates"
else:
    print "G has no isolates"
print "G has density equal to %.4f" %nx.density(G)
if nx.is_weighted(G)==False:
    if G.is_multigraph()==False:
        print "G has transitivity equal to %.4f" %nx.transitivity(G)
    else:
        G1=nx.Graph(G)
        print "G has transitivity equal to %.4f" %nx.transitivity(G1)
else:
    G1=nx.Graph(G)
    print "G has transitivity equal to %.4f" %nx.transitivity(G1)
if G.is_multigraph()==False:
    print "G has reciprocity equal to %.4f" %nx.reciprocity(G)
else:
    G1=nx.Graph(G)
    print "G has reciprocity equal to %.4f" %nx.reciprocity(G1)
# Out:
# G is a multigraph
# G is an unweighted graph
# G is an undirected graph
# G is not a bipartite graph
# G is not a tree
# G is a connected graph
# G has no isolates
# G has density equal to 0.2069
# G has transitivity equal to 0.0000
# G has reciprocity equal to 0.0000

# %% [markdown]
# #### Plotting the multigraph as a weighted graph

# %%
weight=[(x, y, {'weight': v}) for (x, y), v in Counter(G.edges()).items()]
G = nx.Graph(weight)
edge_width=[G[u][v]['weight'] for u,v in G.edges()]

pos=graphviz_layout(G)
plt.figure(figsize=(8,8));
nodes = nx.draw_networkx_nodes(G, pos, node_color="g", alpha=0.3)
nx.draw_networkx_edges(G, pos,arrowsize=20, width=edge_width, edge_color="b", alpha=0.5)
nx.draw_networkx_labels(G, pos)
plt.axis('off');
plt.title(name,fontsize=15);
